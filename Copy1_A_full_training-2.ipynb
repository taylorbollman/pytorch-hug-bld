# %% [markdown]
# # A full training

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
import torch
# %pip install transformers
from transformers import AutoTokenizer, AutoModelForSequenceClassification, DataCollatorWithPadding
from transformers import TrainingArguments, Trainer
import accelerate
from accelerate import Accelerator
import huggingface_hub
# %pip install datasets
from datasets import load_dataset
# Out:
# Requirement already satisfied: transformers in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (4.34.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: requests in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: filelock in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: packaging>=20.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (1.23.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: fsspec in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: datasets in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (2.14.5)
# Requirement already satisfied: requests>=2.19.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: packaging in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (0.17.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: pandas in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: numpy>=1.17 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (1.23.3)
# Requirement already satisfied: aiohttp in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (3.8.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: xxhash in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.4.0)
# Requirement already satisfied: filelock in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/taylorbollman/anaconda3/envs/CS229anacondaTEST/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, DataCollatorWithPadding

raw_datasets = load_dataset("glue", "mrpc")
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)


def tokenize_function(example):
    return tokenizer(example["sentence1"], example["sentence2"], truncation=True)


tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# Map: 100%|██████████| 3668/3668 [00:00<00:00, 27773.39 examples/s]
# Map: 100%|██████████| 408/408 [00:00<00:00, 24814.77 examples/s]
# Map: 100%|██████████| 1725/1725 [00:00<00:00, 29408.29 examples/s]

# %%
tokenized_datasets = tokenized_datasets.remove_columns(["sentence1", "sentence2", "idx"])
tokenized_datasets = tokenized_datasets.rename_column("label", "labels")
tokenized_datasets.set_format("torch")
tokenized_datasets["train"].column_names
# Out:
# ['labels', 'input_ids', 'token_type_ids', 'attention_mask']

# %%
["attention_mask", "input_ids", "labels", "token_type_ids"]
# Out:
# ['attention_mask', 'input_ids', 'labels', 'token_type_ids']

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(
    tokenized_datasets["train"], shuffle=True, batch_size=8, collate_fn=data_collator
)
eval_dataloader = DataLoader(
    tokenized_datasets["validation"], batch_size=8, collate_fn=data_collator
)

# %%
for batch in train_dataloader:
    break
{k: v.shape for k, v in batch.items()}
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'labels': torch.Size([8]),
#  'input_ids': torch.Size([8, 73]),
#  'token_type_ids': torch.Size([8, 73]),
#  'attention_mask': torch.Size([8, 73])}

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)

# %%
outputs = model(**batch)
print(outputs.loss, outputs.logits.shape)
# Out:
# tensor(0.8832, grad_fn=<NllLossBackward0>) torch.Size([8, 2])

# %%
from transformers import AdamW

optimizer = AdamW(model.parameters(), lr=5e-5)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_scheduler

num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)
print(num_training_steps)
# Out:
# 1377

# %%
import torch

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %%
from tqdm.auto import tqdm

progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
#   0%|          | 0/1377 [00:00<?, ?it/s]

# %%
import evaluate

metric = evaluate.load("glue", "mrpc")
model.eval()
for batch in eval_dataloader:
    batch = {k: v.to(device) for k, v in batch.items()}
    with torch.no_grad():
        outputs = model(**batch)

    logits = outputs.logits
    predictions = torch.argmax(logits, dim=-1)
    metric.add_batch(predictions=predictions, references=batch["labels"])

metric.compute()
# Out:
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# {'accuracy': 0.7573529411764706, 'f1': 0.8336134453781512}

# %%
from transformers import AdamW, AutoModelForSequenceClassification, get_scheduler

model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)
optimizer = AdamW(model.parameters(), lr=3e-5)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)

num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(num_epochs):
    for batch in train_dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/1377 [00:00<?, ?it/s]

# %%
from accelerate import Accelerator
from transformers import AdamW, AutoModelForSequenceClassification, get_scheduler

accelerator = Accelerator()

model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)
optimizer = AdamW(model.parameters(), lr=3e-5)

train_dl, eval_dl, model, optimizer = accelerator.prepare(
    train_dataloader, eval_dataloader, model, optimizer
)

num_epochs = 3
num_training_steps = num_epochs * len(train_dl)
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(num_epochs):
    for batch in train_dl:
        outputs = model(**batch)
        loss = outputs.loss
        accelerator.backward(loss)

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/1377 [00:00<?, ?it/s]

# %%
from accelerate import notebook_launcher

notebook_launcher(training_function)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a91f3c0bb4fd> in <cell line: 3>()
#       1 from accelerate import notebook_launcher
#       2
# ----> 3 notebook_launcher(training_function)
#
# NameError: name 'training_function' is not defined
